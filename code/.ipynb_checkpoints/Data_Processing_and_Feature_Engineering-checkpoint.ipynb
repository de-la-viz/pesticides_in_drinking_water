# %% [markdown]
# # Data Processing and Feature Engineering
#
# In this notebook, we merge the different datasets together, select features and engineer some new features. This first step in feature selection and engineering is based on my knowledge of the data.
#
# We proceed in this order:
#
# 1. Filter water systems of interest (active water systems in New England)
# 2. Select features of interest for water systems, and data cleaning
# 3. Filter violations of interest (pesticides)
# 4. Select features of interest for violations, and data cleaning
# 5. Add estimated pesticide use for the water systems
# 6. Merge water systems and violations to obtain violations by water systems (!)
# 7.
# 8. Engineer new features of interest for violations by water systems
#
#
# In the end, we obtain a dateset on which we can do model training and selection. In a later step, when trying different models, a new loop of feature selection and engineering might be needed, and will be performed in a separate notebook.

# %%
import pandas as pd
import numpy as np
import datetime
import time

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import geopandas as gpd # to identify neighboring water systems via ZIP code
from shapely.geometry import Point, Polygon

# %% [markdown]
# ## Water Systems
#
# We did already select the water systems of interest: EPA region 01, New England, and only active water systems.

# %%
# load water systems:
ws_raw = pd.read_csv('../data/active_water_systems_NewEngland.csv')
ws_raw.head().T
# Out:
#                                                    0                    1  \
# Unnamed: 0                                         0                    1
# pwsid                                      ME0004628            ME0092288
# pws_name                        MACHIAS TRAILER PARK  MARSH BROOK ESTATES
# npm_candidate                                      Y                    Y
# primacy_agency_code                               ME                   ME
# epa_region                                         1                    1
# season_begin_date                                NaN                  NaN
# season_end_date                                  NaN                  NaN
# pws_activity_code                                  A                    A
# pws_deactivation_date                            NaN                  NaN
# pws_type_code                                    CWS                  CWS
# dbpr_schedule_cat_code                           NaN                  NaN
# cds_id                                           NaN                  NaN
# gw_sw_code                                        GW                   GW
# lt2_schedule_cat_code                            NaN                  NaN
# owner_type_code                                    P                    P
# population_served_count                           65                   70
# pop_cat_2_code                                     1                    1
# pop_cat_3_code                                     1                    1
# pop_cat_4_code                                     1                    1
# pop_cat_5_code                                     1                    1
# pop_cat_11_code                                    1                    1
# primacy_type                                   State                State
# primary_source_code                               GW                   GW
# is_grant_eligible_ind                              Y                    Y
# is_wholesaler_ind                                  N                    N
# is_school_or_daycare_ind                           N                    N
# service_connections_count                         26                   28
# submission_status_code                             Y                    Y
# org_name                           RADEKA, MICHAEL G     RAUDONIS, WALTER
# admin_name                         RADEKA, MICHAEL G     RAUDONIS, WALTER
# email_addr                       emplumber@yahoo.com   raudonis@gmail.com
# phone_number                            207-263-8320         207-809-8295
# phone_ext_number                                 NaN                  NaN
# fax_number                                       NaN                  NaN
# alt_phone_number                                 NaN                  NaN
# address_line1                        330 MAIN STREET          PO BOX 6518
# address_line2                                    NaN                  NaN
# city_name                                    MACHIAS            HOLLISTON
# zip_code                                       04654                01746
# country_code                                      US                   US
# state_code                                        ME                   MA
# source_water_protection_code                       N                    N
# source_protection_begin_date                     NaN                  NaN
# outstanding_performer                            NaN                  NaN
# outstanding_perform_begin_date                   NaN                  NaN
# cities_served                                MACHIAS              SANFORD
# counties_served                           Washington                 York
# ansi_entity_code                                  29                   31
# county_served                             Washington                 York
#
#                                                               2  \
# Unnamed: 0                                                    2
# pwsid                                                 ME0009198
# pws_name                        TRAILS END STEAK HOUSE & TAVERN
# npm_candidate                                                 Y
# primacy_agency_code                                          ME
# epa_region                                                    1
# season_begin_date                                         01-01
# season_end_date                                           12-31
# pws_activity_code                                             A
# pws_deactivation_date                                       NaN
# pws_type_code                                             TNCWS
# dbpr_schedule_cat_code                                      NaN
# cds_id                                                      NaN
# gw_sw_code                                                   GW
# lt2_schedule_cat_code                                       NaN
# owner_type_code                                               P
# population_served_count                                     390
# pop_cat_2_code                                                1
# pop_cat_3_code                                                1
# pop_cat_4_code                                                1
# pop_cat_5_code                                                1
# pop_cat_11_code                                               2
# primacy_type                                              State
# primary_source_code                                          GW
# is_grant_eligible_ind                                         Y
# is_wholesaler_ind                                             N
# is_school_or_daycare_ind                                      N
# service_connections_count                                     1
# submission_status_code                                        Y
# org_name                                     THOMPSON, SHERRI L
# admin_name                                   THOMPSON, SHERRI L
# email_addr                        trailsendbarandgrille@tds.net
# phone_number                                       207-246-7511
# phone_ext_number                                            NaN
# fax_number                                                  NaN
# alt_phone_number                                            NaN
# address_line1                            59 EUSTIS VILLAGE ROAD
# address_line2                                               NaN
# city_name                                                EUSTIS
# zip_code                                                  04936
# country_code                                                 US
# state_code                                                   ME
# source_water_protection_code                                  N
# source_protection_begin_date                                NaN
# outstanding_performer                                       NaN
# outstanding_perform_begin_date                              NaN
# cities_served                                            EUSTIS
# counties_served                                        Franklin
# ansi_entity_code                                              7
# county_served                                          Franklin
#
#                                                        3  \
# Unnamed: 0                                             3
# pwsid                                          ME0094505
# pws_name                        R & R VACATION HOME PARK
# npm_candidate                                          Y
# primacy_agency_code                                   ME
# epa_region                                             1
# season_begin_date                                  01-01
# season_end_date                                    12-31
# pws_activity_code                                      A
# pws_deactivation_date                                NaN
# pws_type_code                                      TNCWS
# dbpr_schedule_cat_code                               NaN
# cds_id                                               NaN
# gw_sw_code                                            GW
# lt2_schedule_cat_code                                NaN
# owner_type_code                                        P
# population_served_count                               40
# pop_cat_2_code                                         1
# pop_cat_3_code                                         1
# pop_cat_4_code                                         1
# pop_cat_5_code                                         1
# pop_cat_11_code                                        1
# primacy_type                                       State
# primary_source_code                                   GW
# is_grant_eligible_ind                                  Y
# is_wholesaler_ind                                      N
# is_school_or_daycare_ind                               N
# service_connections_count                              1
# submission_status_code                                 Y
# org_name                                  RITCHIE, DONNA
# admin_name                                RITCHIE, DONNA
# email_addr                      jdritchie@roadrunner.com
# phone_number                                305-304-8764
# phone_ext_number                                     NaN
# fax_number                                           NaN
# alt_phone_number                                     NaN
# address_line1                            46 SHIRLEY ROAD
# address_line2                                        NaN
# city_name                                         NAPLES
# zip_code                                           04055
# country_code                                          US
# state_code                                            ME
# source_water_protection_code                           N
# source_protection_begin_date                         NaN
# outstanding_performer                                NaN
# outstanding_perform_begin_date                       NaN
# cities_served                                     NAPLES
# counties_served                               Cumberland
# ansi_entity_code                                       5
# county_served                                 Cumberland
#
#                                                        4
# Unnamed: 0                                             4
# pwsid                                          ME0007311
# pws_name                        NOKOMIS CAMPING AREA LLC
# npm_candidate                                          Y
# primacy_agency_code                                   ME
# epa_region                                             1
# season_begin_date                                  05-01
# season_end_date                                    09-30
# pws_activity_code                                      A
# pws_deactivation_date                                NaN
# pws_type_code                                      TNCWS
# dbpr_schedule_cat_code                               NaN
# cds_id                                               NaN
# gw_sw_code                                            GW
# lt2_schedule_cat_code                                NaN
# owner_type_code                                        P
# population_served_count                              118
# pop_cat_2_code                                         1
# pop_cat_3_code                                         1
# pop_cat_4_code                                         1
# pop_cat_5_code                                         1
# pop_cat_11_code                                        2
# primacy_type                                       State
# primary_source_code                                   GW
# is_grant_eligible_ind                                  Y
# is_wholesaler_ind                                      N
# is_school_or_daycare_ind                               N
# service_connections_count                              1
# submission_status_code                                 Y
# org_name                                     FLECK, RUTH
# admin_name                                   FLECK, RUTH
# email_addr                          nokomis125@gmail.com
# phone_number                                207-583-4411
# phone_ext_number                                     NaN
# fax_number                                           NaN
# alt_phone_number                                     NaN
# address_line1                            49 NOKOMIS ROAD
# address_line2                                        NaN
# city_name                                       HARRISON
# zip_code                                           04040
# country_code                                          US
# state_code                                            ME
# source_water_protection_code                           N
# source_protection_begin_date                         NaN
# outstanding_performer                                NaN
# outstanding_perform_begin_date                       NaN
# cities_served                                   HARRISON
# counties_served                               Cumberland
# ansi_entity_code                                       5
# county_served                                 Cumberland

# %%
# DATA CLEANING FOR WATER SYSTEMS
ws = ws_raw.copy()

# IMPORTANT NOTE: wer cannot use the ZIP code to locate the water systems, 
# as it is sometimes the ZIP code of the legal entity, which is not necessarily in the same place.
# ==> we can locate it with the ansi_entity_code.

# We remove the 6 water systems without localization (no ansi_entity_code)
# (It turns out they are tribal lands) ==> ! introduction of a potential bias
# ws_raw.ansi_entity_code.isnull().sum() 
ws = ws[~ws['ansi_entity_code'].isnull()]

# verifying that the counties_served from the water system table is the same as the county_served from geography:
# (ws.county_served != ws.counties_served).sum()
# so deleting one:
ws.drop('county_served', axis=1, inplace=True)

ws.shape
# Out:
# (10476, 49)

# %%
# First Filter to select needed columns

select_features_ws = ['pwsid', 'pws_name', 'primacy_agency_code', 'pws_type_code', 
                      'gw_sw_code', # if the water system is considered having ground water (“gw”) or surface water (‘sw”) source under SDWA.
                     'owner_type_code', 'population_served_count', 'primary_source_code',
                      'is_wholesaler_ind', # whether the system is a wholesaler of water.
                     'is_school_or_daycare_ind', # if the water system’s primary service area is a school or daycare
                     'service_connections_count', 
                      'source_water_protection_code', # N: WS has not implemented source water protection according to state policy. Y: WS has substantially implemented.
                     # ! source_water_protection_code: most Y only after 01-JAN-2012
                      'cities_served', 'counties_served', 'ansi_entity_code']

ws = ws.loc[:, select_features_ws] # keep only selected columns
ws.head()
# Out:
#        pwsid                         pws_name primacy_agency_code  \
# 0  ME0004628             MACHIAS TRAILER PARK                  ME
# 1  ME0092288              MARSH BROOK ESTATES                  ME
# 2  ME0009198  TRAILS END STEAK HOUSE & TAVERN                  ME
# 3  ME0094505         R & R VACATION HOME PARK                  ME
# 4  ME0007311         NOKOMIS CAMPING AREA LLC                  ME
#
#   pws_type_code gw_sw_code owner_type_code  population_served_count  \
# 0           CWS         GW               P                       65
# 1           CWS         GW               P                       70
# 2         TNCWS         GW               P                      390
# 3         TNCWS         GW               P                       40
# 4         TNCWS         GW               P                      118
#
#   primary_source_code is_wholesaler_ind is_school_or_daycare_ind  \
# 0                  GW                 N                        N
# 1                  GW                 N                        N
# 2                  GW                 N                        N
# 3                  GW                 N                        N
# 4                  GW                 N                        N
#
#    service_connections_count source_water_protection_code cities_served  \
# 0                         26                            N       MACHIAS
# 1                         28                            N       SANFORD
# 2                          1                            N        EUSTIS
# 3                          1                            N        NAPLES
# 4                          1                            N      HARRISON
#
#   counties_served  ansi_entity_code
# 0      Washington              29.0
# 1            York              31.0
# 2        Franklin               7.0
# 3      Cumberland               5.0
# 4      Cumberland               5.0

# %% [markdown]
# ### Adding Geographic Information to the Water Systems
#
# TO BE DONE?
# * = add the shape from shapefile
# * = add Lat/Lon from county (centroid)

# %% [markdown]
# ## Violations
#
# We already filter the data by year, because we are only interested in recent violations. The number of observed violations greatly increased to reach a new plateau in 2009 (known from [previous work](https://github.com/de-la-viz/US-Public-Water-Systems/blob/master/US%20Drinking%20Water%20Quality%20Violations.ipynb)) because of the introduction of new guidelines and rules. We will thus focus on violations from 2009 onwards.

# %%
# load the violations:
violations_raw = pd.read_csv('../data/violations_NewEngland.csv')
# violations_raw.head().T

# %%
# SOME FILTERING AND DATA CLEANING:

violations = violations_raw.copy()

# transform the dates to datetime:
violations.rtc_date = pd.to_datetime(violations.rtc_date)
violations.compl_per_begin_date = pd.to_datetime(violations.compl_per_begin_date)
violations.compl_per_end_date = pd.to_datetime(violations.compl_per_end_date)

violations.loc[:,'year'] = violations['compl_per_begin_date'].dt.year # year when the violation was discovered
violations.loc[:,'month'] = violations['compl_per_begin_date'].dt.month # month when the violation was discovered

# create new column with quarters:
def by_quarter(row):
    if row['month'] < 4:
        return 1
    elif row['month'] >= 4 and row['month'] < 7:
        return 2
    elif row['month'] >= 7 and row['month'] < 10:
        return 3
    else:
        return 4
violations.loc[:,'quarter'] = violations.apply(by_quarter, axis=1) 


select_features_viol = ['pwsid', 'violation_id', 'violation_code', 'violation_category_code', 
                       'is_health_based_ind', 'contaminant_code', 'is_major_viol_ind',
                       'rule_group_code',
                       'year', 'month', 'quarter']

violations = violations.loc[:, select_features_viol] # keep only selected columns

print(violations.shape)
violations.head().T
# Out:
# (100001, 11)
#                                  0          1          2          3          4
# pwsid                    ME0094672  ME0009683  ME0000625  ME0000625  ME0000625
# violation_id                157508      60007       6318       6316       6315
# violation_code                  22         22         75         27         27
# violation_category_code        MCL        MCL      Other         MR         MR
# is_health_based_ind              Y          Y          N          N          N
# contaminant_code              3100       3100       7500       2456       2950
# is_major_viol_ind              NaN        NaN        NaN          Y          Y
# rule_group_code                100        100        400        200        200
# year                          2008       2014       2014       2011       2011
# month                            6          8         10          1          1
# quarter                          2          3          4          1          1

# %% [markdown]
# ### Adding the Contaminant Names

# %%
# loading the contaminants codes:
contaminants = pd.read_csv('../data/contaminant_codes.csv')
contaminants = contaminants.drop('Unnamed: 0', axis=1)
# contaminants.head()

# %%
# merging the name to the violations
violations = violations.merge(contaminants, how='left', on='contaminant_code')

# %% [markdown]
# ### Selection of the Contaminants of Interest: Pesticides
#
# We start by having a quick look at the number of violations for the different pesticides:

# %%
# most occuring contaminants in New Hampshire:
violations.contaminant_name.value_counts().head(50)
# Out:
# COLIFORM (TCR)                   9459
# PUBLIC NOTICE                    2904
# LEAD & COPPER RULE               2217
# NITRATE                          1709
# CONSUMER CONFIDENCE RULE         1385
# ARSENIC                           620
# NITRITE                           560
# E. COLI                           499
# TOTAL HALOACETIC ACIDS (HAA5)     465
# TETRACHLOROETHYLENE               457
# 1,2,4-TRICHLOROBENZENE            450
# TOLUENE                           449
# TRICHLOROETHYLENE                 447
# CIS-1,2-DICHLOROETHYLENE          447
# DICHLOROMETHANE                   446
# STYRENE                           445
# P-DICHLOROBENZENE                 444
# BENZENE                           443
# 1,1,1-TRICHLOROETHANE             443
# 1,1,2-TRICHLOROETHANE             442
# 1,2-DICHLOROETHANE                442
# 1,1-DICHLOROETHYLENE              441
# CHLOROBENZENE                     441
# VINYL CHLORIDE                    441
# TRANS-1,2-DICHLOROETHYLENE        441
# O-DICHLOROBENZENE                 441
# CARBON TETRACHLORIDE              440
# ETHYLBENZENE                      439
# 1,2-DICHLOROPROPANE               438
# TTHM                              410
# CHLORINE                          350
# COMBINED URANIUM                  293
# DI(2-ETHYLHEXYL) PHTHALATE        281
# GROSS ALPHA, EXCL. RADON & U      276
# P-XYLENE                          266
# METHYL TERT-BUTYL ETHER           265
# XYLENES, TOTAL                    259
# TOXAPHENE                         246
# ENDRIN                            243
# METHOXYCHLOR                      243
# BHC-GAMMA                         242
# DI(2-ETHYLHEXYL) ADIPATE          241
# OXAMYL                            238
# SIMAZINE                          236
# CARBOFURAN                        236
# LASSO                             235
# CHLORDANE                         235
# ATRAZINE                          234
# HEXACHLOROCYCLOPENTADIENE         234
# PICLORAM                          234
# Name: contaminant_name, dtype: int64

# %%
# some contaminants name are empty:
violations['contaminant_name'].isnull().sum()
# Out:
# 52392

# %%
# let's check those and find why:
empty_cont_name = violations[violations['contaminant_name'].isnull() == True]
empty_cont_name.contaminant_code.isnull().sum() # only 125 miss a contaminant code
empty_cont_name.contaminant_code.value_counts()
# 8000: not found
# Out:
# 3100.0    11228
# 7500.0     3754
# 5000.0     2706
# 8000.0     2213
# 7000.0     2023
# 1040.0     1746
# 8000       1471
# 3014.0      713
# 1005.0      689
# 2950.0      505
# 2987.0      451
# 1041.0      451
# 2979.0      446
# 2983.0      446
# 2982.0      445
# 2980.0      443
# 2976.0      443
# 2977.0      442
# 2968.0      442
# 2964.0      442
# 2985.0      442
# 2990.0      442
# 2969.0      441
# 2984.0      441
# 2989.0      440
# 2996.0      440
# 2456.0      439
# 2992.0      438
# 2991.0      438
# 2981.0      437
#           ...
# 1022.0       18
# 4102.0       17
# 4174.0       17
# 100.0        16
# 4012.0       15
# 2920.0       13
# 4007.0       11
# 4008.0       11
# 400.0        11
# 4270.0        3
# 4264.0        3
# 1925.0        3
# 4172.0        3
# 1011.0        3
# 4101.0        3
# 1920.0        2
# 600.0         2
# 1002.0        2
# 1009.0        2
# 1008.0        2
# 1013.0        2
# 1905.0        2
# 4044.0        2
# 1006.0        1
# 3015.0        1
# 800.0         1
# 1095.0        1
# 2257.0        1
# 2265.0        1
# 3002.0        1
# Name: contaminant_code, Length: 187, dtype: int64

# %% [markdown]
# We add a new column to the violations to identify pesticides

# %%
# list of pesticides:
pesticide_use_2009_14 = pd.read_csv('../data/pesticide_use/pesticide_use_2009_14.csv')
pesticide_use_2015 = pd.read_csv('../data/pesticide_use/2015PreliminaryEstimates/EPest.county.estimates.2015.txt', sep='\t')
pesticide_use_2016 = pd.read_csv('../data/pesticide_use/2106PreliminaryEstimates/EPest.county.estimates.2016.txt', sep='\t')
pesticide_use_2017 = pd.read_csv('../data/pesticide_use/2017PreliminaryEstimatesNoCA/EPest.county.estimates_noCA.2017.txt', sep='\t')

# append to previous years:
pesticide_use_2009_17 = pesticide_use_2009_14.append(pesticide_use_2015, ignore_index=True)
pesticide_use_2009_17 = pesticide_use_2009_17.append(pesticide_use_2016, ignore_index=True)
pesticide_use_2009_17 = pesticide_use_2009_17.append(pesticide_use_2017, ignore_index=True)

# %%
pesticides = pesticide_use_2009_17.COMPOUND.unique() # a list of all pesticides

# %%
# violations.loc[:,'is_pesticide'] = np.where(violations['contaminant_name'] in pesticides, 1, 0)

violations.apply(lambda x: np.where(violations['contaminant_name'][x] in pesticides, 1, 0), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-aad7edbe7cf4> in <module>
#       1 # violations.loc[:,'is_pesticide'] = np.where(violations['contaminant_name'] in pesticides, 1, 0)
#       2
# ----> 3 violations.apply(lambda x: np.where(violations['contaminant_name'][x] in pesticides, 1, 0), axis=1)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# <ipython-input-171-aad7edbe7cf4> in <lambda>(x)
#       1 # violations.loc[:,'is_pesticide'] = np.where(violations['contaminant_name'] in pesticides, 1, 0)
#       2
# ----> 3 violations.apply(lambda x: np.where(violations['contaminant_name'][x] in pesticides, 1, 0), axis=1)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     906             key = list(key)
#     907
# --> 908         if com.is_bool_indexer(key):
#     909             key = check_bool_indexer(self.index, key)
#     910
#
# /usr/local/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     122             if not lib.is_bool_array(key):
#     123                 if isna(key).any():
# --> 124                     raise ValueError(na_msg)
#     125                 return False
#     126             return True
#
# ValueError: ('cannot index with vector containing NA / NaN values', 'occurred at index 0')

# %%
violations['contaminant_name'][0] in pesticides
# Out:
# False

# %%
violations['contaminant_name'].isnull().sum()
# Out:
# 52392

# %% [markdown]
# TO DO:
#
# 1. ADD THE CONTAMINANTS NAME
# 2. Filter for pesticide

# %%
# Out:
# array(['2,4-D', '2,4-DB', '6-BENZYLADENINE', 'ABAMECTIN', 'ACEPHATE',
#        'ACEQUINOCYL', 'ACETAMIPRID', 'ACETOCHLOR', 'ACIBENZOLAR',
#        'ACIFLUORFEN', 'ALACHLOR', 'ALDICARB', 'ALUMINUM PHOSPHIDE',
#        'AMETRYN', 'AMINOPYRALID', 'AMITRAZ', 'AMPELOMYCES QUISQUALIS',
#        'ASULAM', 'ATRAZINE', 'AVIGLYCINE', 'AZADIRACHTIN',
#        'AZINPHOS-METHYL', 'AZOXYSTROBIN', 'BACILLUS CEREUS',
#        'BACILLUS PUMILIS', 'BACILLUS SUBTILIS', 'BACILLUS THURINGIENSIS',
#        'BENFLURALIN', 'BENOMYL', 'BENSULFURON', 'BENSULIDE', 'BENTAZONE',
#        'BIFENAZATE', 'BIFENTHRIN', 'BISPYRIBAC', 'BOSCALID', 'BROMACIL',
#        'BROMOXYNIL', 'BUPROFEZIN', 'BUTRALIN', 'BUTYLATE',
#        'CALCIUM POLYSULFIDE', 'CAPTAN', 'CARBARYL', 'CARBOFURAN',
#        'CARBOPHENOTHION', 'CARBOXIN', 'CARFENTRAZONE-ETHYL',
#        'CHINOMETHIONAT', 'CHLORANTRANILIPROLE', 'CHLORETHOXYFOS',
#        'CHLORFENAPYR', 'CHLORIDAZON', 'CHLORIMURON', 'CHLORMEQUAT',
#        'CHLORONEB', 'CHLOROPICRIN', 'CHLOROTHALONIL', 'CHLORPROPHAM',
#        'CHLORPYRIFOS', 'CHLORSULFURON', '1-METHYL CYCLOPROPENE',
#        'ALLYL ISOTHIOCYANATE', 'ALPHA CYPERMETHRIN', 'AMECTOCTRADIN',
#        'ASPERGILLUS FLAVUS', 'AUREOBASIDIUM PULLULANS',
#        'BACILLUS AMYLOLIQUIFACIEN', 'BICYCLOPYRONE', 'BLAD PROTEIN',
#        'BURKHOLDERIA CEPACIA', 'BURKHOLDERIA SPP',
#        'CHENOPODIUM AMBROSIOIDES', 'CHROMOBACTERIUM SUBTSUGAE',
#        'CLETHODIM', 'CLODINAFOP', 'CLOFENTEZINE', 'CLOMAZONE',
#        'CLOPYRALID', 'CLORANSULAM-METHYL', 'CLOTHIANIDIN',
#        'CONIOTHYRIUM MINITANS', 'COPPER', 'COPPER HYDROXIDE',
#        'COPPER OCTANOATE', 'COPPER OXYCHLORIDE', 'COPPER OXYCHLORIDE S',
#        'COPPER SULFATE', 'COPPER SULFATE TRIBASIC', 'CPPU', 'CRYOLITE',
#        'CUPROUS OXIDE', 'CYANAMIDE', 'CYANTRANILIPROLE', 'CYAZOFAMID',
#        'CYCLANILIDE', 'CYCLOATE', 'CYDIA POMONELLA', 'CYFLUFENAMID',
#        'CYFLUMETOFEN', 'CYFLUTHRIN', 'CYHALOFOP', 'CYHALOTHRIN-GAMMA',
#        'CYHALOTHRIN-LAMBDA', 'CYMOXANIL', 'CYPERMETHRIN', 'CYPROCONAZOLE',
#        'CYPRODINIL', 'CYROMAZINE', 'CYTOKININ', 'DAMINOZIDE', 'DAZOMET',
#        'DCPA', 'DECAN-1-OL', 'DELTAMETHRIN', 'DESMEDIPHAM', 'DIAZINON',
#        'DICAMBA', 'DICHLOBENIL', 'DICHLOROPROPENE', 'DICHLORPROP',
#        'DICLOFOP', 'DICLORAN', 'DICLOSULAM', 'DICOFOL', 'DICROTOPHOS',
#        'DIENOCHLOR', 'DIETHATYL', 'DIFENOCONAZOLE', 'DIFLUBENZURON',
#        'DIFLUFENZOPYR', 'DIMETHENAMID', 'DIMETHENAMID-P', 'DIMETHOATE',
#        'DIMETHOMORPH', 'DIMETHYL DISULFIDE', 'DINOSEB', 'DINOTEFURAN',
#        'DIQUAT', 'DISULFOTON', 'DITHIOPYR', 'DIURON', 'DODINE',
#        'EMAMECTIN', 'ENDOSULFAN', 'EPTC', 'ESFENVALERATE',
#        'ETHALFLURALIN', 'ETHEPHON', 'ETHION', 'ETHOFUMESATE',
#        'ETHOPROPHOS', 'ETOXAZOLE', 'ETRIDIAZOLE', 'FAMOXADONE',
#        'FATTY ALCOHOLS', 'FENAMIDONE', 'FENARIMOL', 'FENAZAQUIN',
#        'FENBUCONAZOLE', 'FENBUTATIN OXIDE', 'FENHEXAMID', 'FENOXAPROP',
#        'FENOXYCARB', 'FENPROPATHRIN', 'FENPYROXIMATE', 'FENTIN', 'FERBAM',
#        'FIPRONIL', 'FLAZASULFURON', 'FLONICAMID', 'FLORASULAM',
#        'FLUAZIFOP', 'FLUAZINAM', 'FLUBENDIAMIDE', 'FLUCARBAZONE',
#        'FLUDIOXONIL', 'FLUFENACET', 'FLUMETRALIN', 'FLUMETSULAM',
#        'FLUMICLORAC', 'FLUMIOXAZIN', 'FLUOMETURON', 'FLUOPICOLIDE',
#        'FLUOPYRAM', 'FLUOXASTROBIN', 'FLUPYRADIFURONE', 'FLURIDONE',
#        'FLUROXYPYR', 'FLUTHIACET-METHYL', 'FLUTOLANIL', 'FLUTRIAFOL',
#        'FLUVALINATE TAU', 'FLUXAPYROXAD', 'FOMESAFEN', 'FORAMSULFURON',
#        'FORMETANATE', 'FOSETYL', 'GALLEX', 'GAMMA AMINOBUTYRIC ACID',
#        'GARLIC JUICE', 'GIBBERELLIC ACID', 'GLIOCLADIUM VIRENS',
#        'GLUFOSINATE', 'GLYPHOSATE', 'HALOSULFURON', 'HARPIN PROTEIN',
#        'HEXAZINONE', 'HEXYTHIAZOX', 'HYDRAMETHYLNON', 'HYDRATED LIME',
#        'HYDROGEN PEROXIDE', 'IBA', 'IMAZALIL', 'IMAZAMETHABENZ',
#        'IMAZAMOX', 'IMAZAPIC', 'IMAZAPYR', 'IMAZAQUIN', 'IMAZETHAPYR',
#        'IMAZOSULFURON', 'IMIDACLOPRID', 'INDAZIFLAM', 'INDOXACARB',
#        'IODOSULFURON', 'IPCONAZOLE', 'IPRODIONE', 'ISARIA FUMOSOROSEA',
#        'ISOFETAMID', 'ISOXABEN', 'ISOXAFLUTOLE', 'KAOLIN CLAY',
#        'KASUGAMYCIN', 'KINOPRENE', 'KRESOXIM-METHYL', 'L-GLUTAMIC ACID',
#        'LACTOFEN', 'LINDANE', 'LINURON', 'MALATHION', 'MALEIC HYDRAZIDE',
#        'MANCOZEB', 'MANDIPROPAMID', 'MANEB', 'MCPA', 'MCPB', 'MECOPROP',
#        'MEFENOXAM', 'MEPIQUAT', 'MESOSULFURON', 'MESOTRIONE', 'METALAXYL',
#        'METALDEHYDE', 'METAM', 'METAM POTASSIUM', 'METCONAZOLE',
#        'METHIDATHION', 'METHIOCARB', 'METHOMYL', 'METHOXYFENOZIDE',
#        'METHYL BROMIDE', 'METHYL PARATHION', 'METIRAM', 'METOLACHLOR',
#        'METOLACHLOR-S', 'METRAFENONE', 'METRIBUZIN', 'METSULFURON',
#        'MEVINPHOS', 'MSMA', 'MYCLOBUTANIL', 'MYROTHECIUM VERRUCARIA',
#        'NALED', 'NAPHTHYLACETAMIDE', 'NAPHTHYLACETIC ACID', 'NAPROPAMIDE',
#        'NAPTALAM', 'NEEM OIL', 'NICOSULFURON', 'NORFLURAZON',
#        'NOSEMA LOCUSTAE CANN', 'NOVALURON', 'ORTHOSULFAMURON', 'ORYZALIN',
#        'OXADIAZON', 'OXAMYL', 'OXYDEMETON-METHYL', 'OXYFLUORFEN',
#        'OXYTETRACYCLINE', 'PACLOBUTRAZOL', 'PAECILOMYCES LILACINUS',
#        'PARAQUAT', 'PARATHION', 'PELARGONIC ACID', 'PENDIMETHALIN',
#        'PENOXSULAM', 'PENTHIOPYRAD', 'PERMETHRIN', 'PETROLEUM DISTILLATE',
#        'PETROLEUM OIL', 'PHENMEDIPHAM', 'PHORATE', 'PHOSMET',
#        'PHOSPHORIC ACID', 'PICLORAM', 'PICOXYSTROBIN', 'PINOLENE',
#        'PINOXADEN', 'PIPERONYL BUTOXIDE', 'POLYHEDROSIS VIRUS',
#        'POLYOXORIM', 'POTASSIUM BICARBONATE', 'POTASSIUM OLEATE',
#        'POTASSIUM SILICATE', 'PRIMISULFURON', 'PRODIAMINE',
#        'PROHEXADIONE', 'PROMETON', 'PROMETRYN', 'PROPAMOCARB HCL',
#        'PROPANIL', 'PROPARGITE', 'PROPAZINE', 'PROPICONAZOLE', 'PROPOXUR',
#        'PROPOXYCARBAZONE', 'PROPYZAMIDE', 'PROSULFURON',
#        'PROTHIOCONAZOLE', 'PSEUDOMONAS FLUORESCENS', 'PYMETROZINE',
#        'PYRACLOSTROBIN', 'PYRAFLUFEN ETHYL', 'PYRASULFOTOLE',
#        'PYRETHRINS', 'PYRIDABEN', 'PYRIMETHANIL', 'PYRIPROXYFEN',
#        'PYRITHIOBAC-SODIUM', 'PYROXASULFONE', 'PYROXSULAM', 'QUINCLORAC',
#        'QUINOXYFEN', 'QUINTOZENE', 'QUIZALOFOP',
#        'REYNOUTRIA SACHALINENSIS', 'RIMSULFURON', 'ROTENONE', 'SABADILLA',
#        'SAFLUFENACIL', 'SETHOXYDIM', 'SILICATES', 'SIMAZINE',
#        'SODIUM CHLORATE', 'SPINETORAM', 'SPINOSYN', 'SPIRODICLOFEN',
#        'SPIROMESIFEN', 'SPIROTETRAMAT', 'STREPTOMYCES LYDICUS',
#        'STREPTOMYCIN', 'SUCROSE OCTANOATE', 'SULFCARBAMIDE',
#        'SULFENTRAZONE', 'SULFOMETURON', 'SULFOSULFURON', 'SULFOXAFLOR',
#        'SULFUR', 'SULFURIC ACID', 'TCMTB', 'TEBUCONAZOLE', 'TEBUFENOZIDE',
#        'TEBUPIRIMPHOS', 'TEBUTHIURON', 'TEFLUTHRIN', 'TEMBOTRIONE',
#        'TERBACIL', 'TERBUFOS', 'TETRABOROHYDRATE', 'TETRACONAZOLE',
#        'TETRATHIOCARBONATE', 'THIABENDAZOLE', 'THIACLOPRID',
#        'THIAMETHOXAM', 'THIDIAZURON', 'THIENCARBAZONE-METHYL',
#        'THIFENSULFURON', 'THIOBENCARB', 'THIODICARB',
#        'THIOPHANATE-METHYL', 'THIRAM', 'TOLFENPYRAD', 'TOPRAMEZONE',
#        'TRALKOXYDIM', 'TRI-ALLATE', 'TRIADIMEFON', 'TRIASULFURON',
#        'TRIBENURON METHYL', 'TRIBUFOS', 'TRICLOPYR', 'TRIFLOXYSTROBIN',
#        'TRIFLOXYSULFURON', 'TRIFLUMIZOLE', 'TRIFLURALIN',
#        'TRIFLUSULFURON', 'TRINEXAPAC', 'TRITICONAZOLE', 'UNICONAZOLE',
#        'VINCLOZOLIN', 'ZETA-CYPERMETHRIN', 'ZINC', 'ZIRAM', 'ZOXAMIDE',
#        'AMITROLE', 'BACTERIOPHAGE', 'BENZOVIDIFLUPYR',
#        'DIMETHENAMID & DIMETHENAMID-P', 'ENDOTHAL', 'EPN', 'FLUENSULFONE',
#        'FOLPET', 'METHOXYCHLOR', 'METOLACHLOR & METOLACHLOR-S',
#        'OXATHIAPIPROLIN', 'PHOSPHAMIDON', 'RESMETHRIN',
#        'SODIUM METABORATE', 'TERBUTRYN', 'ABSCISIC ACID',
#        'BACILLUS MYCOIDES', 'BEAUVERIA BASSIANA', 'BLADPROTEIN',
#        'HALAUXIFEN', 'POTASSIUMSILICATE', 'PROHYDROJASMON'], dtype=object)

# %% [markdown]
# ## Merging all SDWIS Together
#
# We first add the contaminants codes information to the violations.

# %%
# merging contaminants codes with violations

violations = violations.merge(contaminant_codes, how='left', on='contaminant_code') # we want to keep all violations

# %% [markdown]
# We then merge the water systems and violations by _PWSID_ (it is not a 1 to 1 relation).

# %%
# merging water systems with violations:

# 1 water system might see several violations, 
# and 1 violation might affect several water sytems (albeit it is rare)
NE_viol = water_system.merge(violations, how='outer')

# %%
# pesticides

# %%
# the years 2013 to 2017 are estimates.
# the years 2015 to 2017 are not direclty accessible yet. 
# we first have to download them, then I reload them here:

pesticide_use_2015 = pd.read_csv('../data/pesticide_use/2015PreliminaryEstimates/EPest.county.estimates.2015.txt', sep='\t')
pesticide_use_2016 = pd.read_csv('../data/pesticide_use/2106PreliminaryEstimates/EPest.county.estimates.2016.txt', sep='\t')
pesticide_use_2017 = pd.read_csv('../data/pesticide_use/2017PreliminaryEstimatesNoCA/EPest.county.estimates_noCA.2017.txt', sep='\t')

# append to previous years:
pesticide_use_2009_17 = pesticide_use_2009_14.append(pesticide_use_2015, ignore_index=True)

print(pesticide_use_2009_17.shape)
pesticide_use_2009_17.head()
