# %%
I_WANT_TO_RESAVE_THE_DATA = False # overwrite previously saved data if you run the full notebook
# else, go case by case and run chunk after chunk.

# %% [markdown]
# # Data Extraction
#
# The aim of this notebook is to extract the different datasets that will be used later.
#
# I first extract data from EPA's Safe Drinking Water Information System ([SDWIS](https://www.epa.gov/enviro/sdwis-model)) for the [water systems](https://enviro.epa.gov/enviro/ef_metadata_html.ef_metadata_table?p_table_name=WATER_SYSTEM&p_topic=SDWIS), for their characteristics (notably where the ZIP code where they are situated) and for the Maximum Contaminant Levels (MCLs) [violations](https://enviro.epa.gov/enviro/ef_metadata_html.ef_metadata_table?p_table_name=VIOLATION&p_topic=SDWIS) (notably which contaminants and when).
#
# Then, the datasets are saved and reloaded in the _Data_Processing_and_Feature_Engineering_ notebook.

# %%
import pandas as pd
import datetime

import requests # to read the data from the REST API of EPA Envirofacts
import csv # needed as data accessed through the REST API are .csv (other possibilities are .xml or .xls)

# %% [markdown]
# ## Extracting Water Systems Data from SDWIS

# %%
# more on the API: https://www.epa.gov/enviro/envirofacts-data-service-api

# notes on the API:
#     - WATER_SYSTEM = table name
#     - PWS_ACTIVITY_CODE/A ==> select only active water systems
#     - EPA_REGION/01 ==> New England

CSV_URL = 'https://enviro.epa.gov/enviro/efservice/WATER_SYSTEM/EPA_REGION/01/PWS_ACTIVITY_CODE/A/CSV'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    initial_WS = list(cr)        
    WATER_SYSTEM_raw = pd.DataFrame(initial_WS)
print(WATER_SYSTEM_raw.shape)
WATER_SYSTEM_raw.head()
# Out:
# (10483, 48)
#                    0                                1   \
# 0  WATER_SYSTEM.PWSID            WATER_SYSTEM.PWS_NAME
# 1           ME0004628             MACHIAS TRAILER PARK
# 2           ME0092288              MARSH BROOK ESTATES
# 3           ME0009198  TRAILS END STEAK HOUSE & TAVERN
# 4           ME0094505         R & R VACATION HOME PARK
#
#                            2                                 3   \
# 0  WATER_SYSTEM.NPM_CANDIDATE  WATER_SYSTEM.PRIMACY_AGENCY_CODE
# 1                           Y                                ME
# 2                           Y                                ME
# 3                           Y                                ME
# 4                           Y                                ME
#
#                         4                               5   \
# 0  WATER_SYSTEM.EPA_REGION  WATER_SYSTEM.SEASON_BEGIN_DATE
# 1                       01
# 2                       01
# 3                       01                           01-01
# 4                       01                           01-01
#
#                              6                               7   \
# 0  WATER_SYSTEM.SEASON_END_DATE  WATER_SYSTEM.PWS_ACTIVITY_CODE
# 1                                                             A
# 2                                                             A
# 3                         12-31                               A
# 4                         12-31                               A
#
#                                    8                           9   ...  \
# 0  WATER_SYSTEM.PWS_DEACTIVATION_DATE  WATER_SYSTEM.PWS_TYPE_CODE  ...
# 1                                                             CWS  ...
# 2                                                             CWS  ...
# 3                                                           TNCWS  ...
# 4                                                           TNCWS  ...
#
#                       38                         39                       40  \
# 0  WATER_SYSTEM.ZIP_CODE  WATER_SYSTEM.COUNTRY_CODE  WATER_SYSTEM.STATE_CODE
# 1                  04654                         US                       ME
# 2                  01746                         US                       MA
# 3                  04936                         US                       ME
# 4                  04055                         US                       ME
#
#                                           41  \
# 0  WATER_SYSTEM.SOURCE_WATER_PROTECTION_CODE
# 1                                          N
# 2                                          N
# 3                                          N
# 4                                          N
#
#                                           42  \
# 0  WATER_SYSTEM.SOURCE_PROTECTION_BEGIN_DATE
# 1
# 2
# 3
# 4
#
#                                    43  \
# 0  WATER_SYSTEM.OUTSTANDING_PERFORMER
# 1
# 2
# 3
# 4
#
#                                             44                          45  \
# 0  WATER_SYSTEM.OUTSTANDING_PERFORM_BEGIN_DATE  WATER_SYSTEM.CITIES_SERVED
# 1                                                                  MACHIAS
# 2                                                                  SANFORD
# 3                                                                   EUSTIS
# 4                                                                   NAPLES
#
#                              46    47
# 0  WATER_SYSTEM.COUNTIES_SERVED
# 1                    Washington  None
# 2                          York  None
# 3                      Franklin  None
# 4                    Cumberland  None
#
# [5 rows x 48 columns]

# %%
# Some Data Cleaning:

water_system = WATER_SYSTEM_raw.copy()

# set the first row as header:
new_header = water_system.iloc[0] # grab the first row for the header
new_header = new_header.str.split('.').str[1] # we remove the redundant table name (WATER_SYSTEM) in column names
new_header = new_header.str.lower() # set to lower case, as less annoying
water_system = water_system[1:] # take the data less the header row
water_system.columns = new_header # set the header row as the df header

# I remove the last column of null, that is an artifact of the extraction:
water_system = water_system.dropna(axis = 1, how='all') # axis = 1 = columns

water_system.tail() # looks good for now.
# Out:
# 0          pwsid                       pws_name npm_candidate  \
# 10478  NH1108030            WINDY RIDGE ORCHARD             Y
# 10479  NH1109020  MOUNTAIN VALLEY TREATMENT CTR             Y
# 10480  NH1112010                STONEGATE ACRES             Y
# 10481  NH1113010            HILLSIDE INN CONDOS             Y
# 10482  NH1117010         CAMP BEREA/DINING HALL             Y
#
# 0     primacy_agency_code epa_region season_begin_date season_end_date  \
# 10478                  NH         01             06-01           10-31
# 10479                  NH         01             01-01           12-31
# 10480                  NH         01
# 10481                  NH         01
# 10482                  NH         01             01-01           12-31
#
# 0     pws_activity_code pws_deactivation_date pws_type_code  ...  city_name  \
# 10478                 A                               TNCWS  ...  HAVERHILL
# 10479                 A                               TNCWS  ...     ORFORD
# 10480                 A                                 CWS  ...    CONCORD
# 10481                 A                                 CWS  ...     HEBRON
# 10482                 A                               TNCWS  ...     HEBRON
#
# 0     zip_code country_code state_code source_water_protection_code  \
# 10478    03774           US         NH
# 10479    03777           US         NH
# 10480    03302           US         NH
# 10481    03241           US         NH
# 10482    03241           US         NH
#
# 0     source_protection_begin_date outstanding_performer  \
# 10478
# 10479
# 10480
# 10481
# 10482
#
# 0     outstanding_perform_begin_date cities_served counties_served
# 10478                                    HAVERHILL         Grafton
# 10479                                    HAVERHILL         Grafton
# 10480                                       HEBRON         Grafton
# 10481                                       HEBRON         Grafton
# 10482                                       HEBRON         Grafton
#
# [5 rows x 47 columns]

# %% [markdown]
# ### Extracting Geographic Information for the Water Systems from SDWIS
#
# The table water system contains more information about the _legal entity_, i.e. who owns the water system, but we wat to know where exactly it is located.

# %%
# more on the API: https://www.epa.gov/enviro/envirofacts-data-service-api

# notes on the API:
#     - WATER_SYSTEM = table name
#     - no filter on PWS_ACTIVITY_CODE/A ==> it is done on the water systems.
#     - EPA_REGION/01 ==> New England
#     - area_type_code/CN ==> COUNTY LEVEL. location of the water system at the county level.

CSV_URL = 'https://enviro.epa.gov/enviro/efservice/GEOGRAPHIC_AREA/EPA_REGION/01/area_type_code/CN/CSV'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    initial_WS = list(cr)        
    GEO_WS_raw = pd.DataFrame(initial_WS)
print(GEO_WS_raw.shape)
GEO_WS_raw.head()
# Out:
# (29218, 14)
#                       0                       1   \
# 0  GEOGRAPHIC_AREA.PWSID  GEOGRAPHIC_AREA.GEO_ID
# 1              ME0008039                22175401
# 2              VT0001269                22174342
# 3              ME0092365                22175066
# 4              ME0092366                22175073
#
#                                     2                           3   \
# 0  GEOGRAPHIC_AREA.PRIMACY_AGENCY_CODE  GEOGRAPHIC_AREA.EPA_REGION
# 1                                   ME                          01
# 2                                   VT                          01
# 3                                   ME                          01
# 4                                   ME                          01
#
#                                   4                              5   \
# 0  GEOGRAPHIC_AREA.PWS_ACTIVITY_CODE  GEOGRAPHIC_AREA.PWS_TYPE_CODE
# 1                                  A                          TNCWS
# 2                                  I                          TNCWS
# 3                                  A                            CWS
# 4                                  A                            CWS
#
#                             6                             7   \
# 0  GEOGRAPHIC_AREA.TRIBAL_CODE  GEOGRAPHIC_AREA.STATE_SERVED
# 1
# 2
# 3
# 4
#
#                                  8                                9   \
# 0  GEOGRAPHIC_AREA.ANSI_ENTITY_CODE  GEOGRAPHIC_AREA.ZIP_CODE_SERVED
# 1                               027
# 2                               003
# 3                               005
# 4                               031
#
#                             10                              11  \
# 0  GEOGRAPHIC_AREA.CITY_SERVED  GEOGRAPHIC_AREA.AREA_TYPE_CODE
# 1                                                           CN
# 2                                                           CN
# 3                                                           CN
# 4                                                           CN
#
#                               12    13
# 0  GEOGRAPHIC_AREA.COUNTY_SERVED
# 1                          Waldo  None
# 2                     Bennington  None
# 3                     Cumberland  None
# 4                           York  None

# %%
# Some Data Cleaning:

geo_ws = GEO_WS_raw.copy()

# set the first row as header:
new_header = geo_ws.iloc[0] # grab the first row for the header
new_header = new_header.str.split('.').str[1] # we remove the redundant table name (WATER_SYSTEM) in column names
new_header = new_header.str.lower() # set to lower case, as less annoying
geo_ws = geo_ws[1:] # take the data less the header row
geo_ws.columns = new_header # set the header row as the df header

# I remove the last column of null, that is an artifact of the extraction:
geo_ws = geo_ws.dropna(axis = 1, how='all') # axis = 1 = columns

geo_ws.sort_values(by='pwsid', inplace=True)

geo_ws # looks good.
# Out:
# 0          pwsid    geo_id primacy_agency_code epa_region pws_activity_code  \
# 8229   010502001  22029509                  01         01                 I
# 17203  CT0000251  21986138                  CT         01                 I
# 17204  CT0010011  21986139                  CT         01                 N
# 17205  CT0010012  21986141                  CT         01                 I
# 17206  CT0010021  21986142                  CT         01                 I
# 17207  CT0010022  21986143                  CT         01                 I
# 24339  CT0010024  21942120                  CT         01                 A
# 17208  CT0010032  21986144                  CT         01                 I
# 17209  CT0010042  21986145                  CT         01                 I
# 24340  CT0010044  21942122                  CT         01                 A
# 17210  CT0010052  21986146                  CT         01                 I
# 24341  CT0010054  21942125                  CT         01                 A
# 17211  CT0010062  21986147                  CT         01                 I
# 1104   CT0010064  22089338                  CT         01                 I
# 17212  CT0010072  21986148                  CT         01                 I
# 1105   CT0010074  22089340                  CT         01                 I
# 17213  CT0010082  21986149                  CT         01                 I
# 24342  CT0010084  21942127                  CT         01                 A
# 17214  CT0010092  21986150                  CT         01                 I
# 24343  CT0010094  21942129                  CT         01                 A
# 23977  CT0010102  21960484                  CT         01                 A
# 1106   CT0010104  22089342                  CT         01                 N
# 23132  CT0010111  21933304                  CT         01                 A
# 17215  CT0010112  21986151                  CT         01                 I
# 8688   CT0010114  21980143                  CT         01                 I
# 17216  CT0010123  21986152                  CT         01                 I
# 13065  CT0010124  21939018                  CT         01                 A
# 17217  CT0010132  21986153                  CT         01                 I
# 26571  CT0010153  22111215                  CT         01                 N
# 17218  CT0011102  21986154                  CT         01                 I
# ...          ...       ...                 ...        ...               ...
# 3569   VT0021534  22265224                  VT         01                 A
# 3570   VT0021535  22265226                  VT         01                 A
# 3571   VT0021546  22265228                  VT         01                 A
# 3572   VT0021548  22265230                  VT         01                 A
# 12741  VT0021549  22270441                  VT         01                 A
# 12742  VT0021550  22270443                  VT         01                 A
# 12743  VT0021553  22270445                  VT         01                 A
# 12744  VT0021556  22270447                  VT         01                 A
# 12745  VT0021562  22270449                  VT         01                 A
# 12746  VT0021563  22270451                  VT         01                 A
# 12747  VT0021564  22270453                  VT         01                 A
# 12748  VT0021568  22270455                  VT         01                 A
# 12749  VT0021570  22270457                  VT         01                 A
# 12750  VT0021571  22270459                  VT         01                 A
# 12751  VT0021574  22270461                  VT         01                 A
# 12752  VT0021577  22270463                  VT         01                 A
# 12753  VT0021580  22270465                  VT         01                 A
# 12754  VT0021584  22270467                  VT         01                 A
# 12755  VT0021585  22270469                  VT         01                 A
# 12756  VT0021586  22270471                  VT         01                 A
# 12757  VT0021587  22270473                  VT         01                 A
# 12758  VT0021593  22270475                  VT         01                 A
# 12759  VT0021594  22270477                  VT         01                 A
# 12761  VT0021596  22270481                  VT         01                 A
# 12760  VT0021599  22270479                  VT         01                 A
# 12762  VT0021601  22270483                  VT         01                 A
# 12763  VT0021603  22270485                  VT         01                 A
# 12764  VT0021604  22270487                  VT         01                 A
# 13883  VT0021608  22270489                  VT         01                 A
# 13884  VT0021612  22270491                  VT         01                 A
#
# 0     pws_type_code tribal_code state_served ansi_entity_code zip_code_served  \
# 8229          TNCWS                                       009
# 17203           CWS                                       013
# 17204           CWS                                       013
# 17205         TNCWS                                       013
# 17206         TNCWS                                       013
# 17207         TNCWS                                       013
# 24339         TNCWS                                       013
# 17208         TNCWS                                       013
# 17209         TNCWS                                       013
# 24340         TNCWS                                       013
# 17210         TNCWS                                       013
# 24341         TNCWS                                       013
# 17211         TNCWS                                       013
# 1104          TNCWS                                       013
# 17212         TNCWS                                       013
# 1105         NTNCWS                                       013
# 17213         TNCWS                                       013
# 24342         TNCWS                                       013
# 17214         TNCWS                                       013
# 24343        NTNCWS                                       013
# 23977        NTNCWS                                       013
# 1106          TNCWS                                       013
# 23132           CWS                                       013
# 17215         TNCWS                                       013
# 8688          TNCWS                                       013
# 17216        NTNCWS                                       013
# 13065         TNCWS                                       013
# 17217         TNCWS                                       013
# 26571        NTNCWS                                       013
# 17218         TNCWS                                       013
# ...             ...         ...          ...              ...             ...
# 3569          TNCWS                                       011
# 3570          TNCWS                                       001
# 3571          TNCWS                                       003
# 3572          TNCWS                                       025
# 12741         TNCWS                                       023
# 12742         TNCWS                                       013
# 12743         TNCWS                                       027
# 12744         TNCWS                                       013
# 12745         TNCWS                                       003
# 12746         TNCWS                                       003
# 12747         TNCWS                                       023
# 12748         TNCWS                                       021
# 12749           CWS                                       021
# 12750         TNCWS                                       011
# 12751         TNCWS                                       021
# 12752         TNCWS                                       011
# 12753         TNCWS                                       003
# 12754         TNCWS                                       019
# 12755        NTNCWS                                       005
# 12756         TNCWS                                       005
# 12757         TNCWS                                       021
# 12758         TNCWS                                       027
# 12759         TNCWS                                       015
# 12761        NTNCWS                                       007
# 12760         TNCWS                                       001
# 12762         TNCWS                                       021
# 12763         TNCWS                                       021
# 12764         TNCWS                                       025
# 13883         TNCWS                                       011
# 13884         TNCWS                                       003
#
# 0     city_served area_type_code county_served
# 8229                          CN
# 17203                         CN       Tolland
# 17204                         CN       Tolland
# 17205                         CN       Tolland
# 17206                         CN       Tolland
# 17207                         CN       Tolland
# 24339                         CN       Tolland
# 17208                         CN       Tolland
# 17209                         CN       Tolland
# 24340                         CN       Tolland
# 17210                         CN       Tolland
# 24341                         CN       Tolland
# 17211                         CN       Tolland
# 1104                          CN       Tolland
# 17212                         CN       Tolland
# 1105                          CN       Tolland
# 17213                         CN       Tolland
# 24342                         CN       Tolland
# 17214                         CN       Tolland
# 24343                         CN       Tolland
# 23977                         CN       Tolland
# 1106                          CN       Tolland
# 23132                         CN       Tolland
# 17215                         CN       Tolland
# 8688                          CN       Tolland
# 17216                         CN       Tolland
# 13065                         CN       Tolland
# 17217                         CN       Tolland
# 26571                         CN       Tolland
# 17218                         CN       Tolland
# ...           ...            ...           ...
# 3569                          CN      Franklin
# 3570                          CN       Addison
# 3571                          CN    Bennington
# 3572                          CN       Windham
# 12741                         CN    Washington
# 12742                         CN    Grand Isle
# 12743                         CN       Windsor
# 12744                         CN    Grand Isle
# 12745                         CN    Bennington
# 12746                         CN    Bennington
# 12747                         CN    Washington
# 12748                         CN       Rutland
# 12749                         CN       Rutland
# 12750                         CN      Franklin
# 12751                         CN       Rutland
# 12752                         CN      Franklin
# 12753                         CN    Bennington
# 12754                         CN       Orleans
# 12755                         CN     Caledonia
# 12756                         CN     Caledonia
# 12757                         CN       Rutland
# 12758                         CN       Windsor
# 12759                         CN      Lamoille
# 12761                         CN    Chittenden
# 12760                         CN       Addison
# 12762                         CN       Rutland
# 12763                         CN       Rutland
# 12764                         CN       Windham
# 13883                         CN      Franklin
# 13884                         CN    Bennington
#
# [29217 rows x 13 columns]

# %%
# Keep only the necessary columns.
# the ZIP code is droped because it is mostly empty, unfortunately, 
# EVEN at the city level (i.e. without the filter area_type_code==CN)

ws_county = geo_ws[['pwsid', 'ansi_entity_code', 'county_served']]

# %%
# I link this information to the water systems:

water_system = water_system.merge(ws_county, how='left')
water_system.shape
# Out:
# (10482, 49)

# %%
# I save the raw "clean" data as csv, in case the API should stop to work in the future:
if I_WANT_TO_RESAVE_THE_DATA:
    water_system.to_csv('../data/active_water_systems_NewEngland.csv')

# %% [markdown]
# ## Extracting Violations Data from SDWIS

# %%
# more on the API: https://www.epa.gov/enviro/envirofacts-data-service-api

# notes on the API:
#     - VIOLATION = table name
#     - EPA_REGION/01 ==> New England
# note that we do not filter here for active water systems. It will be done when merging with water systems.

CSV_URL = 'https://enviro.epa.gov/enviro/efservice/VIOLATION/EPA_REGION/01/CSV'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    initial_V = list(cr)        
    VIOLATIONS_raw = pd.DataFrame(initial_V)
print(VIOLATIONS_raw.shape)
VIOLATIONS_raw.head()
# Out:
# (100002, 35)
#                 0                       1                      2   \
# 0  VIOLATION.PWSID  VIOLATION.VIOLATION_ID  VIOLATION.FACILITY_ID
# 1        ME0094672                  157508
# 2        ME0009683                   60007
# 3        ME0000625                    6318
# 4        ME0000625                    6316
#
#                                   3                        4   \
# 0  VIOLATION.POPULATION_SERVED_COUNT  VIOLATION.NPM_CANDIDATE
# 1                                388                        N
# 2                                454                        N
# 3                                100                        N
# 4                                100                        N
#
#                             5                                6   \
# 0  VIOLATION.PWS_ACTIVITY_CODE  VIOLATION.PWS_DEACTIVATION_DATE
# 1                            A
# 2                            A
# 3                            A
# 4                            A
#
#                               7                         8   \
# 0  VIOLATION.PRIMARY_SOURCE_CODE  VIOLATION.POP_CAT_5_CODE
# 1                             GW                         1
# 2                             GW                         1
# 3                             GW                         1
# 4                             GW                         1
#
#                               9   ...                            25  \
# 0  VIOLATION.PRIMACY_AGENCY_CODE  ...  VIOLATION.RTC_ENFORCEMENT_ID
# 1                             ME  ...
# 2                             ME  ...                          1510
# 3                             ME  ...                        638928
# 4                             ME  ...                        638930
#
#                    26                                  27  \
# 0  VIOLATION.RTC_DATE  VIOLATION.PUBLIC_NOTIFICATION_TIER
# 1                                                       2
# 2           08-SEP-14                                   2
# 3           04-NOV-13                                   3
# 4           13-AUG-14                                   3
#
#                           28                          29  \
# 0  VIOLATION.ORIGINATOR_CODE  VIOLATION.SAMPLE_RESULT_ID
# 1                          S
# 2                          S
# 3                          S
# 4                          S
#
#                                30                   31  \
# 0  VIOLATION.CORRECTIVE_ACTION_ID  VIOLATION.RULE_CODE
# 1                                                  110
# 2                                                  110
# 3                                                  410
# 4                                                  210
#
#                           32                          33    34
# 0  VIOLATION.RULE_GROUP_CODE  VIOLATION.RULE_FAMILY_CODE
# 1                        100                         110  None
# 2                        100                         110  None
# 3                        400                         410  None
# 4                        200                         210  None
#
# [5 rows x 35 columns]

# %%
# Some Data Cleaning:

violations = VIOLATIONS_raw.copy()

# set the first row as header:
new_header = violations.iloc[0] # grab the first row for the header
new_header = new_header.str.split('.').str[1] # we remove the redundant table name (VIOLATION) in column names
new_header = new_header.str.lower() # set to lower case, as less annoying
violations = violations[1:] # take the data less the header row
violations.columns = new_header # set the header row as the df header

# I remove the last column of null, that is an artifact of the extraction:
violations = violations.dropna(axis = 1, how='all') # axis = 1 = columns

# transform the dates to datetime:
violations.rtc_date = pd.to_datetime(violations.rtc_date)
violations.compl_per_begin_date = pd.to_datetime(violations.compl_per_begin_date)
violations.compl_per_end_date = pd.to_datetime(violations.compl_per_end_date)

violations.tail() # looks good for now.
# Out:
# 0           pwsid violation_id facility_id population_served_count  \
# 99997   CT0970184          611                                  38
# 99998   CT0580124       171808                                  35
# 99999   CT0580124       171106                                  35
# 100000  CT0580124       172909                                  35
# 100001  ME0004962        38516                                 150
#
# 0      npm_candidate pws_activity_code pws_deactivation_date  \
# 99997              N                 A
# 99998              N                 A
# 99999              N                 A
# 100000             N                 A
# 100001             N                 A
#
# 0      primary_source_code pop_cat_5_code primacy_agency_code  ...  \
# 99997                   GW              1                  CT  ...
# 99998                   GW              1                  CT  ...
# 99999                   GW              1                  CT  ...
# 100000                  GW              1                  CT  ...
# 100001                  GW              1                  ME  ...
#
# 0      latest_enforcement_id rtc_enforcement_id   rtc_date  \
# 99997                    322                322 2013-12-16
# 99998                   3608               3608 2008-05-22
# 99999                   2206               2206 2005-11-14
# 100000                  4826               4819 2009-06-30
# 100001                437450             437450 2015-05-27
#
# 0      public_notification_tier originator_code sample_result_id  \
# 99997                         3               S
# 99998                         3               S
# 99999                         3               S
# 100000                        3               S
# 100001                        3               S
#
# 0      corrective_action_id rule_code rule_group_code rule_family_code
# 99997                             410             400              410
# 99998                             110             100              110
# 99999                             410             400              410
# 100000                            110             100              110
# 100001                            410             400              410
#
# [5 rows x 34 columns]

# %%
violations.rtc_date.describe()
# Out:
# count                   90296
# unique                   4572
# top       2015-03-05 00:00:00
# freq                     1340
# first     1984-02-01 00:00:00
# last      2018-09-21 00:00:00
# Name: rtc_date, dtype: object

# %%
# I save the raw "clean" data as csv, in case the API should stop to work in the future:
if I_WANT_TO_RESAVE_THE_DATA:
    violations.to_csv('../data/violations_NewEngland.csv')

# %% [markdown]
# We know have downloaded all the necessary data from SDWIS. In the future, it could eventually be possible to download data from other SDWIS table to feed in the model.
#
# ### Contaminant Codes
#
# To get the names of the contaminants.

# %%
contaminant_codes_raw = pd.read_csv('../data/SDWISCodesforLABs/Analyte Codes-Table.csv')
print(contaminant_codes_raw.shape)
contaminant_codes_raw.head()
# Out:
# (768, 9)
#    CODE                  NAME SCIENTIFIC_NAME TYPE_CODE CAS_REGISTRY_NUM  \
# 0  0100             TURBIDITY             NaN        WQ              NaN
# 1  0200                  SWTR             NaN        RL              NaN
# 2  0300                IESWTR             NaN        RL              NaN
# 3  0400           DBP STAGE 1             NaN        RL              NaN
# 4  0500  FILTER BACKWASH RULE             NaN        RL              NaN
#
#   CFR_SECTION_REF_CD REPORTABLE_STR_DAT REPORTABLE_END_DAT STATE_CLASS_CODE
# 0             141.13                NaN                NaN              WQP
# 1                NaN                NaN                NaN              NaN
# 2                NaN                NaN                NaN              NaN
# 3                NaN                NaN                NaN              NaN
# 4                NaN                NaN                NaN              NaN

# %%
# contaminant_codes_raw.CODE.unique()

# %%
# Some Data Cleaning
contaminant_codes = contaminant_codes_raw.copy()

contaminant_codes = contaminant_codes[['CODE', 'NAME', 'TYPE_CODE']] # columns of interest

contaminant_codes = contaminant_codes.rename(index=str, columns={"CODE": "contaminant_code", 
                                                                "NAME": "contaminant_name",
                                                                "TYPE_CODE": "contaminant_type_code"})

# not necessary:
# # remove the "categories" of contaminants, that contain ***
# contaminant_codes = contaminant_codes[contaminant_codes['CODE'].str.isdigit()] # keep only digits

contaminant_codes.head()
# Out:
#   contaminant_code      contaminant_name contaminant_type_code
# 0             0100             TURBIDITY                    WQ
# 1             0200                  SWTR                    RL
# 2             0300                IESWTR                    RL
# 3             0400           DBP STAGE 1                    RL
# 4             0500  FILTER BACKWASH RULE                    RL

# %%
# Save as csv in case:
if I_WANT_TO_RESAVE_THE_DATA:
    contaminant_codes.to_csv('../data/contaminant_codes.csv')

# %% [markdown]
# ## Estimated Annual Agricultural Pesticide Use, from NAWQA
#
# The **estimated** annual agricultural pesticide use is collected by the National Water-Quality Assessment (NAWQA) Project, from the US Department of the Interior ([see here](https://water.usgs.gov/nawqa/pnsp/usage/maps/index.php)). This data list an estimated pesticide use, by pesticide, county and year.
#
# Data collected with a farm survey:
# "For all States except California, proprietary farm survey pesticide-use data are aggregated and reported at the multi-county Crop Reporting District (CRD) level. Harvested-crop acreage data by county from the U.S. Department of Agriculture Census of Agriculture are used to calculate the median pesticide-by- crop use rates for each crop in each CRD. These rates are applied to the harvested acreage of each crop in a county to obtain pesticide-use estimates at a county level."
#
# Caution:
# "These pesticide-use estimates are suitable for evaluating national and regional patterns and trends of annual pesticide use. The reliability of estimates, however, generally decreases with scale and these estimates and maps are not intended for detailed evaluations, such as comparing within or between specific individual counties."

# %%
# get the data:

# the years 2009-2014 are directly accessible via URL:

# I first query to get the first year (2009), and then we will append more years:
URL = 'https://water.usgs.gov/nawqa/pnsp/usage/maps/county-level/PesticideUseEstimates/EPest.county.estimates.2009.txt'
pesticide_use_2009_14 = pd.read_csv(URL, sep='\t')

years = ['2010', '2011', '2012', '2013', '2014']
for year in years:
    if year in ['2010', '2011', '2012']:
        URL = 'https://water.usgs.gov/nawqa/pnsp/usage/maps/county-level/PesticideUseEstimates/EPest.county.estimates.' +\
        year + '.txt'
        pesticide_use_thisyear = pd.read_csv(URL, sep='\t')
    else: # 2013 and 2014 are preliminary estimates with a different URL
        URL = 'https://water.usgs.gov/nawqa/pnsp/usage/maps/county-level/PreliminaryEstimates/EPest.county.estimates.' +\
        year + '.txt'
        pesticide_use_thisyear = pd.read_csv(URL, sep='\t')
    pesticide_use_2009_14 = pesticide_use_2009_14.append(pesticide_use_thisyear, ignore_index=True)

print(pesticide_use_2009_14.shape)
pesticide_use_2009_14.head()
# Out:
# (2251527, 6)
#   COMPOUND  YEAR  STATE_FIPS_CODE  COUNTY_FIPS_CODE  EPEST_LOW_KG  \
# 0    2,4-D  2009                1                 1         597.5
# 1    2,4-D  2009                1                 3        3351.0
# 2    2,4-D  2009                1                 5        8158.1
# 3    2,4-D  2009                1                 7          53.8
# 4    2,4-D  2009                1                 9       12369.3
#
#    EPEST_HIGH_KG
# 0          986.4
# 1         4858.5
# 2         8219.1
# 3           98.8
# 4        12646.9

# %%
pesticide_use_2009_14.YEAR.unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014])

# %%
# Save as csv in case:
if I_WANT_TO_RESAVE_THE_DATA: # smaller than 100MB. 2009-17 just too large...
    pesticide_use_2009_14.to_csv('../data/pesticide_use/pesticide_use_2009_14.csv')

# %% [markdown]
# The data for the years 2015, 2016 and 2017 have been downloaded manually, are found in the folders (data/pesticide_use), and will be loaded and merged in the next phase: Data Processing and Feature Engineering.
